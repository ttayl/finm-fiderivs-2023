# %% [markdown]
# # Build Final Exam Data

# %%
import numpy as np
import pandas as pd

import sys
sys.path.insert(0, '../cmds')
from ratecurves import *
from ficcvol import *
from binomial import *

from datetime import datetime
import warnings

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (12,6)
plt.rcParams['font.size'] = 15
plt.rcParams['legend.fontsize'] = 13

from matplotlib.ticker import (MultipleLocator,
                               FormatStrFormatter,
                               AutoMinorLocator)

# %% [markdown]
# ***

# %%
DATE = '2023-05-05'
FILEIN = f'../build_data/cap_curves_{DATE}.xlsx'

# %% [markdown]
# ### Export Curves to Excel

# %%
SAVEDATA = False
FILEOUT = f'exam_data_{DATE}'

# %% [markdown]
# # Market Data

# %% [markdown]
# ### Load Curves

# %%
Tdata = 3.25
curves = pd.read_excel(FILEIN, sheet_name=f'rate curves {DATE}').set_index('tenor')
curves
# Out:
#        swap rates  discounts  forwards  flat vols  fwd vols
# tenor
# 0.25     0.050719   0.987479       NaN        NaN       NaN
# 0.50     0.050123   0.975402  0.049527   0.316162  0.316162
# 0.75     0.048560   0.964447  0.045435   0.347778  0.372145
# 1.00     0.046639   0.954690  0.040881   0.379394  0.428165
# 1.25     0.044145   0.946600  0.034187   0.461469  0.668067
# 1.50     0.041930   0.939349  0.030874   0.520051  0.698306
# 1.75     0.040224   0.932356  0.030003   0.558612  0.688861
# 2.00     0.038818   0.925648  0.028986   0.580620  0.659912
# 2.25     0.037466   0.919518  0.026665   0.589547  0.612262
# 2.50     0.036468   0.913240  0.027499   0.588862  0.563661
# 2.75     0.035670   0.906959  0.027700   0.582035  0.519747
# 3.00     0.035026   0.900667  0.027946   0.572538  0.490527
# 3.25     0.034423   0.894584  0.027198   0.563103  0.475147
# 3.50     0.033893   0.888583  0.027013   0.553514  0.459513
# 3.75     0.033492   0.882433  0.027881   0.542818  0.436853
# 4.00     0.033165   0.876242  0.028261   0.530062  0.399064
# 4.25     0.032851   0.870186  0.027835   0.514761  0.347591
# 4.50     0.032583   0.864131  0.028032   0.498297  0.309934
# 4.75     0.032400   0.857888  0.029108   0.482522  0.296876
# 5.00     0.032272   0.851537  0.029832   0.469288  0.306231
# 5.25     0.032158   0.845224  0.029878   0.459888  0.336103
# 5.50     0.032052   0.838966  0.029833   0.453392  0.361974
# 5.75     0.031957   0.832747  0.029874   0.448312  0.372543
# 6.00     0.031876   0.826545  0.030012   0.443160  0.362621
# 6.25     0.031811   0.820345  0.030235   0.436805  0.333663
# 6.50     0.031759   0.814145  0.030459   0.429541  0.307192
# 6.75     0.031718   0.807954  0.030652   0.422017  0.290260
# 7.00     0.031685   0.801779  0.030804   0.414882  0.284665
# 7.25     0.031659   0.795629  0.030920   0.408618  0.289174
# 7.50     0.031639   0.789499  0.031057   0.403026  0.291865
# 7.75     0.031626   0.783383  0.031232   0.397736  0.288559
# 8.00     0.031620   0.777272  0.031449   0.392382  0.278083
# 8.25     0.031622   0.771160  0.031699   0.386697  0.261628
# 8.50     0.031632   0.765052  0.031939   0.380826  0.247727
# 8.75     0.031647   0.758951  0.032154   0.375019  0.239158
# 9.00     0.031666   0.752864  0.032339   0.369523  0.236658
# 9.25     0.031688   0.746799  0.032489   0.364587  0.241041
# 9.50     0.031712   0.740762  0.032599   0.360458  0.253228
# 9.75     0.031736   0.734762  0.032663   0.357385  0.274305
# 10.00    0.031760   0.728808  0.032676   0.355617  0.305634

# %%
curves = curves.loc[:Tdata,['discounts','fwd vols']]
curves
# Out:
#        discounts  fwd vols
# tenor
# 0.25    0.987479       NaN
# 0.50    0.975402  0.316162
# 0.75    0.964447  0.372145
# 1.00    0.954690  0.428165
# 1.25    0.946600  0.668067
# 1.50    0.939349  0.698306
# 1.75    0.932356  0.688861
# 2.00    0.925648  0.659912
# 2.25    0.919518  0.612262
# 2.50    0.913240  0.563661
# 2.75    0.906959  0.519747
# 3.00    0.900667  0.490527
# 3.25    0.894584  0.475147

# %% [markdown]
# ### BDT Tree

# %%
quotes = curves['discounts']*100

sigmas = curves['fwd vols']
sigmas.iloc[0] = sigmas.iloc[1]

theta, ratetree = estimate_theta(sigmas,quotes)
format_bintree(theta.to_frame().T, style='{:.2%}')

format_bintree(ratetree,style='{:.2%}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_50ec1">
#   <thead>
#     <tr>
#       <th class="index_name level0" >time</th>
#       <th id="T_50ec1_level0_col0" class="col_heading level0 col0" >0.00</th>
#       <th id="T_50ec1_level0_col1" class="col_heading level0 col1" >0.25</th>
#       <th id="T_50ec1_level0_col2" class="col_heading level0 col2" >0.50</th>
#       <th id="T_50ec1_level0_col3" class="col_heading level0 col3" >0.75</th>
#       <th id="T_50ec1_level0_col4" class="col_heading level0 col4" >1.00</th>
#       <th id="T_50ec1_level0_col5" class="col_heading level0 col5" >1.25</th>
#       <th id="T_50ec1_level0_col6" class="col_heading level0 col6" >1.50</th>
#       <th id="T_50ec1_level0_col7" class="col_heading level0 col7" >1.75</th>
#       <th id="T_50ec1_level0_col8" class="col_heading level0 col8" >2.00</th>
#       <th id="T_50ec1_level0_col9" class="col_heading level0 col9" >2.25</th>
#       <th id="T_50ec1_level0_col10" class="col_heading level0 col10" >2.50</th>
#       <th id="T_50ec1_level0_col11" class="col_heading level0 col11" >2.75</th>
#       <th id="T_50ec1_level0_col12" class="col_heading level0 col12" >3.00</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >state</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_50ec1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_50ec1_row0_col0" class="data row0 col0" >5.04%</td>
#       <td id="T_50ec1_row0_col1" class="data row0 col1" >5.69%</td>
#       <td id="T_50ec1_row0_col2" class="data row0 col2" >6.11%</td>
#       <td id="T_50ec1_row0_col3" class="data row0 col3" >6.49%</td>
#       <td id="T_50ec1_row0_col4" class="data row0 col4" >6.50%</td>
#       <td id="T_50ec1_row0_col5" class="data row0 col5" >7.13%</td>
#       <td id="T_50ec1_row0_col6" class="data row0 col6" >8.56%</td>
#       <td id="T_50ec1_row0_col7" class="data row0 col7" >10.37%</td>
#       <td id="T_50ec1_row0_col8" class="data row0 col8" >12.12%</td>
#       <td id="T_50ec1_row0_col9" class="data row0 col9" >16.07%</td>
#       <td id="T_50ec1_row0_col10" class="data row0 col10" >21.02%</td>
#       <td id="T_50ec1_row0_col11" class="data row0 col11" >27.78%</td>
#       <td id="T_50ec1_row0_col12" class="data row0 col12" >35.66%</td>
#     </tr>
#     <tr>
#       <th id="T_50ec1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_50ec1_row1_col0" class="data row1 col0" ></td>
#       <td id="T_50ec1_row1_col1" class="data row1 col1" >4.15%</td>
#       <td id="T_50ec1_row1_col2" class="data row1 col2" >4.45%</td>
#       <td id="T_50ec1_row1_col3" class="data row1 col3" >4.73%</td>
#       <td id="T_50ec1_row1_col4" class="data row1 col4" >4.74%</td>
#       <td id="T_50ec1_row1_col5" class="data row1 col5" >5.20%</td>
#       <td id="T_50ec1_row1_col6" class="data row1 col6" >6.24%</td>
#       <td id="T_50ec1_row1_col7" class="data row1 col7" >7.56%</td>
#       <td id="T_50ec1_row1_col8" class="data row1 col8" >8.84%</td>
#       <td id="T_50ec1_row1_col9" class="data row1 col9" >11.71%</td>
#       <td id="T_50ec1_row1_col10" class="data row1 col10" >15.33%</td>
#       <td id="T_50ec1_row1_col11" class="data row1 col11" >20.25%</td>
#       <td id="T_50ec1_row1_col12" class="data row1 col12" >25.99%</td>
#     </tr>
#     <tr>
#       <th id="T_50ec1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_50ec1_row2_col0" class="data row2 col0" ></td>
#       <td id="T_50ec1_row2_col1" class="data row2 col1" ></td>
#       <td id="T_50ec1_row2_col2" class="data row2 col2" >3.07%</td>
#       <td id="T_50ec1_row2_col3" class="data row2 col3" >3.26%</td>
#       <td id="T_50ec1_row2_col4" class="data row2 col4" >3.26%</td>
#       <td id="T_50ec1_row2_col5" class="data row2 col5" >3.58%</td>
#       <td id="T_50ec1_row2_col6" class="data row2 col6" >4.30%</td>
#       <td id="T_50ec1_row2_col7" class="data row2 col7" >5.21%</td>
#       <td id="T_50ec1_row2_col8" class="data row2 col8" >6.09%</td>
#       <td id="T_50ec1_row2_col9" class="data row2 col9" >8.07%</td>
#       <td id="T_50ec1_row2_col10" class="data row2 col10" >10.56%</td>
#       <td id="T_50ec1_row2_col11" class="data row2 col11" >13.96%</td>
#       <td id="T_50ec1_row2_col12" class="data row2 col12" >17.92%</td>
#     </tr>
#     <tr>
#       <th id="T_50ec1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_50ec1_row3_col0" class="data row3 col0" ></td>
#       <td id="T_50ec1_row3_col1" class="data row3 col1" ></td>
#       <td id="T_50ec1_row3_col2" class="data row3 col2" ></td>
#       <td id="T_50ec1_row3_col3" class="data row3 col3" >2.12%</td>
#       <td id="T_50ec1_row3_col4" class="data row3 col4" >2.13%</td>
#       <td id="T_50ec1_row3_col5" class="data row3 col5" >2.33%</td>
#       <td id="T_50ec1_row3_col6" class="data row3 col6" >2.80%</td>
#       <td id="T_50ec1_row3_col7" class="data row3 col7" >3.39%</td>
#       <td id="T_50ec1_row3_col8" class="data row3 col8" >3.97%</td>
#       <td id="T_50ec1_row3_col9" class="data row3 col9" >5.26%</td>
#       <td id="T_50ec1_row3_col10" class="data row3 col10" >6.88%</td>
#       <td id="T_50ec1_row3_col11" class="data row3 col11" >9.10%</td>
#       <td id="T_50ec1_row3_col12" class="data row3 col12" >11.68%</td>
#     </tr>
#     <tr>
#       <th id="T_50ec1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_50ec1_row4_col0" class="data row4 col0" ></td>
#       <td id="T_50ec1_row4_col1" class="data row4 col1" ></td>
#       <td id="T_50ec1_row4_col2" class="data row4 col2" ></td>
#       <td id="T_50ec1_row4_col3" class="data row4 col3" ></td>
#       <td id="T_50ec1_row4_col4" class="data row4 col4" >1.09%</td>
#       <td id="T_50ec1_row4_col5" class="data row4 col5" >1.20%</td>
#       <td id="T_50ec1_row4_col6" class="data row4 col6" >1.44%</td>
#       <td id="T_50ec1_row4_col7" class="data row4 col7" >1.74%</td>
#       <td id="T_50ec1_row4_col8" class="data row4 col8" >2.03%</td>
#       <td id="T_50ec1_row4_col9" class="data row4 col9" >2.70%</td>
#       <td id="T_50ec1_row4_col10" class="data row4 col10" >3.53%</td>
#       <td id="T_50ec1_row4_col11" class="data row4 col11" >4.66%</td>
#       <td id="T_50ec1_row4_col12" class="data row4 col12" >5.99%</td>
#     </tr>
#     <tr>
#       <th id="T_50ec1_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_50ec1_row5_col0" class="data row5 col0" ></td>
#       <td id="T_50ec1_row5_col1" class="data row5 col1" ></td>
#       <td id="T_50ec1_row5_col2" class="data row5 col2" ></td>
#       <td id="T_50ec1_row5_col3" class="data row5 col3" ></td>
#       <td id="T_50ec1_row5_col4" class="data row5 col4" ></td>
#       <td id="T_50ec1_row5_col5" class="data row5 col5" >0.60%</td>
#       <td id="T_50ec1_row5_col6" class="data row5 col6" >0.71%</td>
#       <td id="T_50ec1_row5_col7" class="data row5 col7" >0.87%</td>
#       <td id="T_50ec1_row5_col8" class="data row5 col8" >1.01%</td>
#       <td id="T_50ec1_row5_col9" class="data row5 col9" >1.34%</td>
#       <td id="T_50ec1_row5_col10" class="data row5 col10" >1.76%</td>
#       <td id="T_50ec1_row5_col11" class="data row5 col11" >2.32%</td>
#       <td id="T_50ec1_row5_col12" class="data row5 col12" >2.98%</td>
#     </tr>
#     <tr>
#       <th id="T_50ec1_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_50ec1_row6_col0" class="data row6 col0" ></td>
#       <td id="T_50ec1_row6_col1" class="data row6 col1" ></td>
#       <td id="T_50ec1_row6_col2" class="data row6 col2" ></td>
#       <td id="T_50ec1_row6_col3" class="data row6 col3" ></td>
#       <td id="T_50ec1_row6_col4" c

# %% [markdown]
# ## CTD Table

# %%
tv = ratetree.copy()[1]
mask = ~tv.isna()

NOMDISC = .06
cpns = np.array([.01,.01,.045,.045,.045])
out = pd.DataFrame(100*price_bond(tv[mask], 2, cpns,face=1, accr_frac = 0) / price_bond(NOMDISC, 2, cpns,face=1, accr_frac = 0)).rename(columns={1:'CTD price at expry'}).round(2)

out
# Out:
#        CTD price at expry
# state
# 0                   99.05
# 1                  102.47
# 2                  105.31
# 3                  107.62
# 4                  109.79

# %% [markdown]
# ### Save Data

# %%
if SAVEDATA:
    outfile = f'../data/{FILEOUT}.xlsx'
    with pd.ExcelWriter(outfile) as writer:  
        curves.to_excel(writer, sheet_name= f'rate curves', index=True)
        ratetree.to_excel(writer, sheet_name= f'rate tree', index=True)
